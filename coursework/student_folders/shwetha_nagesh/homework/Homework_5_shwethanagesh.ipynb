# %% [markdown]
# ### ASTR 8070: Astrostatistics
# ***N. Pol***
# ___
#
# # Homework 5
# ### Due: Friday, Mar 7nd at 11.59pm CST
# ---

# %% [markdown]
# ## Only one problem this week
#
# This problem uses a dataset in `/coursework/homeworks/hw_data/`.
#
# 1) Read in `hw5_data_1.npy`. This is a (100 x 3) numpy array, containing some time-series measurements. It could be flux measurements from a star or some other transient. The first column is time (arbitrary units), the second column is the flux (arbitrary units), and the third column are homoescedastic measurement uncertainties on the flux. Plot this data with the uncertainties.
#
# 2) One possible model for this data is a sharp burst with an exponential tail rising above a nominal background level. This model can be described as:
#
# $y = b$, for $t<t_0$
#
# $y = b + A\exp[-\alpha(t-t_0)]$, for $t\geq t_0$
#
# where $b$ is the background amplitude, $A$ is the burst amplitude, $t_0$ is the burst epoch, and $\alpha$ encodes how rapidly the burst dies off.
#
# Code this burst model, and code a likelihood function for this data with the burst model. *Hint: This is similar in spirit to the likelihood when fitting polynomials to data, except now $x$ is time, and the polynomial model is now the burst model.*
#
# 3) Using one of the MCMC codes that we looked at in class (`emcee`, `pymc3`, `PTMCMCSampler`) perform a Bayesian analysis that recovers an MCMC chain of posterior probability samples for the joint parameter space of $\{b,A,t_0,\alpha\}$. You must decide on how many samples are appropriate for running your MCMC. For your priors, make them $b\in \mathrm{Uniform}[0,50]$, $A\in \mathrm{Uniform}[0,50]$, $t_0\in \mathrm{Uniform}[0,100]$, and $\ln\alpha\in \mathrm{Uniform}[-5,5]$.
#
# 4) Perform an appropriate check to burn-in your chain, and thin the chain by selecting only points every auto-correlation length. If you are left with a small number of samples after thinning then you may need to run your MCMC for longer in (3).
#
# 5) Make a corner plot of the $4$-D parameter space, with labels, $[68,95]\%$ credible levels and quantiles, and titles.
#
# 6) Now choose $100$ samples randomly from your burned, thinned chain and plot the $100$ corresponding burst time-series on a figure along with the original data. You may want to choose a transparency for these $100$ burst curves that allows you to see everything nicely. These are showing the posterior spread of model solutions that are consistent with the data.
#
# 7) Another possible model that may explain the data is a Gaussian profile described by:
#
# $y = b + A\exp[-(t-t_0)^2 / 2\sigma_W^2]$
#
# The priors for this model are the same as above for the equivalent parameters, and with $\ln\sigma_W\in\mathrm{Uniform}[-2,2]$. Following the examples from `Lecture 12` and from relevant web tutorials/documentation, use one of the nested sampling packages (`dynesty` or `UltraNest`) to compute the Bayesian evidence for this Gaussian model, and for the original burst model. Compute the Bayes factor, and state which model is the favored description of the data. *Hint: Be careful with how you transform your parameter space into a unit hypercube for the nested sampling priors. An appropriate check on whether you have done things correctly is that the posterior samples you get from the burst analysis here should give an equivalent corner plot to the MCMC you did above.*

# %% [markdown]
# ### Solution

# %%
import numpy as np
import matplotlib.pyplot as plt
import emcee
import corner
from dynesty import NestedSampler
from scipy.optimize import minimize

# %% [markdown]
# Solution: 1

# %%
data = np.load("/home/shwetha/repos/ASTR_3300_S2025/coursework/homeworks/hw_data/hw5_data_1.npy")
time = data[:,0]
flux = data[:,1]
flux_err = data[:,-1]

plt.errorbar(time, flux, yerr=flux_err, fmt='.')
plt.title('Lightcurve')
plt.xlabel('Time')
plt.ylabel('Flux')
plt.show()

# %% [markdown]
# Solution: 2

# %%
def burst_modelling(t, b, A, t0, alpha):
    y = np.where(t < t0, b, b+A*np.exp(-alpha*(t-t0)))
    return y

def logL(par, t, y, y_err):
    b, A, t0, log_alpha = par
    alpha = np.exp(log_alpha)
    model_y = burst_modelling(t, b, A, t0, alpha)
    log_likelihood = -0.5 * np.sum(((flux-model_y)/flux_err)**2+np.log(2*np.pi*flux_err**2))
    return log_likelihood

# %% [markdown]
# Solution: 3

# %%
def log_prior(par):
    b, A, t0, log_alpha = par
    if 0 < b < 50 and 0 < A < 50 and 0 < t0 < 100 and -5 < log_alpha < 5:
        return 0.0
    return -np.inf

# Define the log-posterior function
def log_posterior(par, time, flux, flux_err):
    lp = log_prior(par)
    if not np.isfinite(lp):
        return -np.inf
    return lp + logL(par, time, flux, flux_err)



dim = 4
num_walkers = 50
num_steps = 5000
burnin = 1000

p0 = np.array([np.random.uniform(0, 50, num_walkers),
               np.random.uniform(0, 50, num_walkers),
               np.random.uniform(0, 100, num_walkers),
               np.random.uniform(-5, 5, num_walkers)]).T

# %% [markdown]
# Solution: 4 and 5

# %%
test = emcee.EnsembleSampler(num_walkers, dim, log_posterior, args=(time, flux, flux_err))
test.run_mcmc(p0, num_steps, progress=True)

samples = test.get_chain(discard=burnin, thin=10, flat=True)


labels = [r'$b$', r'$A$', r'$t_0$', r'$\alpha$']
fig = corner.corner(samples, labels=labels, quantiles=[0.16, 0.5, 0.84], show_titles=True)
plt.show()
# Out:
# /tmp/ipykernel_11110/2535027144.py:2: RuntimeWarning: overflow encountered in exp
#   y = np.where(t < t0, b, b+A*np.exp(-alpha*(t-t0)))
# /tmp/ipykernel_11110/2535027144.py:2: RuntimeWarning: overflow encountered in multiply
#   y = np.where(t < t0, b, b+A*np.exp(-alpha*(t-t0)))
# WARNING:emcee.pbar:You must install the tqdm library to use progress indicators with emcee
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# Solution: 6

# %%
plt.errorbar(time, flux, yerr=flux_err, fmt='.', color='black')
sample_size=100
for i in samples[np.random.choice(len(samples), sample_size)]:
    plt.plot(time, burst_modelling(time, i[0] , i[1] , i[2] , np.exp(i[3])), 0.1, color='blue')

plt.xlabel('Time')
plt.ylim(6,16.5)
plt.ylabel('Flux')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_11110/212834266.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Solution: 7

# %%
def gaussian_model(t, b, A, t0, sigma_W):
    return b + A * np.exp(-((t - t0)**2) / (2 * sigma_W**2))


def prior_transform(u):
    b = 50 * u[0]  # Uniform[0,50]
    A = 50 * u[1]  # Uniform[0,50]
    t0 = 100 * u[2]  # Uniform[0,100]
    log_param = -5 + 10 * u[3] if model_type == "burst" else -2 + 4 * u[3]  # log_alpha or log_sigma_W
    return b, A, t0, log_param

def log_L_gauss(params, time, flux, flux_err):
    b, A, t0, log_sigma_w = params
    sigma_w = np.exp(log_sigma_w)
    y_model = gaussian_model(time, b, A, t0, sigma_w)
    return -0.5 * np.sum(((flux - y_model) / flux_err) ** 2 + np.log(2 * np.pi * flux_err ** 2))


sampler = NestedSampler(log_L_gauss, prior_transform, ndim=4, logl_args=(time, flux, flux_err))
sampler.run_nested()
results = sampler.results
logZ_gaussian = results.logz[-1]


sampler_g = NestedSampler(logL, prior_transform, ndim=4, logl_args=(time, flux, flux_err))
sampler_g.run_nested()
results_burst = sampler_g.results
logZ_burst = results_burst.logz[-1]


# Compute Bayes Factor
"""logZ_burst = results.logz[-1] if model_type == "burst" else logZ_burst
logZ_gaussian = results.logz[-1] if model_type == "gaussian" else logZ_gaussian"""
bayes_factor = np.exp(logZ_burst - logZ_gaussian)


print(f"Bayes Factor (Burst/Gaussian) = {bayes_factor}")
if bayes_factor > 1:
    print("Burst model is preferred.")
elif bayes_factor < 1:
    print("Gaussian model is preferred.")
else:
    print("Models are equally probable.")
# Out:
# iter: 4085 | bound: 59 | nc: 15 | ncall: 62270 | eff(%):  6.560 | loglstar:   -inf < -178.549 <    inf | logz: -186.444 +/-  0.117 | dlogz: 29.861 >  0.509                                           /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# iter: 4094 | bound: 66 | nc: 39 | ncall: 67655 | eff(%):  6.051 | loglstar:   -inf < -178.483 <    inf | logz: -186.430 +/-  0.117 | dlogz: 29.829 >  0.509                                           /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# iter: 4095 | bound: 69 | nc: 1676 | ncall: 69331 | eff(%):  5.906 | loglstar:   -inf < -178.478 <    inf | logz: -186.428 +/-  0.117 | dlogz: 29.825 >  0.509                                         /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# iter: 4099 | bound: 71 | nc: 55 | ncall: 71397 | eff(%):  5.741 | loglstar:   -inf < -178.462 <    inf | logz: -186.422 +/-  0.117 | dlogz: 29.969 >  0.509                                           /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# iter: 4108 | bound: 73 | nc: 34 | ncall: 72933 | eff(%):  5.633 | loglstar:   -inf < -178.347 <    inf | logz: -186.407 +/-  0.117 | dlogz: 29.936 >  0.509                                           /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# iter: 4109 | bound: 76 | nc: 2133 | ncall: 75066 | eff(%):  5.474 | loglstar:   -inf < -178.336 <    inf | logz: -186.405 +/-  0.117 | dlogz: 29.933 >  0.509                                         /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# iter: 4110 | bound: 77 | nc: 583 | ncall: 75649 | eff(%):  5.433 | loglstar:   -inf < -178.324 <    inf | logz: -186.403 +/-  0.117 | dlogz: 29.929 >  0.509                                          /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# iter: 4111 | bound: 79 | nc: 1486 | ncall: 77135 | eff(%):  5.330 | loglstar:   -inf < -178.312 <    inf | logz: -186.402 +/-  0.117 | dlogz: 29.925 >  0.509                                         /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# iter: 4779 | bound: 118 | nc: 26 | ncall: 106731 | eff(%):  4.478 | loglstar:   -inf < -168.609 <    inf | logz: -179.918 +/-  0.142 | dlogz: 24.898 >  0.509                                         /home/shwetha/miniconda3/envs/astr3300/lib/python3.12/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# iter: 149 | bound: 0 | nc: 1 | ncall: 675 | eff(%): 22.074 | loglstar:   -inf < -37030.184 <    inf | logz: -37037.389 +/-  0.120 | dlogz: 37007.135 >  0.509                                         /tmp/ipykernel_11110/188716658.py:2: RuntimeWarning: overflow encountered in exp
#   y = np.where(t < t0, b, b+A*np.exp(-alpha*(t-t0)))
# iter: 599 | bound: 0 | nc: 3 | ncall: 1607 | eff(%): 37.274 | loglstar:   -inf < -3546.211 <    inf | logz: -3554.310 +/-  0.127 | dlogz: 3379.700 >  0.509                                           /tmp/ipykernel_11110/188716658.py:2: RuntimeWarning: overflow encountered in multiply
#   y = np.where(t < t0, b, b+A*np.exp(-alpha*(t-t0)))
# iter: 2252 | bound: 5 | nc: 12 | ncall: 21615 | eff(%): 10.419 | loglstar:   -inf < -205.508 <    inf | logz: -213.373 +/-  0.118 | dlogz: 49.940 >  0.509                                            /tmp/ipykernel_11110/188716658.py:2: RuntimeWarning: overflow encountered in exp
#   y = np.where(t < t0, b, b+A*np.exp(-alpha*(t-t0)))
# iter: 2703 | bound: 12 | nc: 13 | ncall: 26527 | eff(%): 10.190 | loglstar:   -inf < -185.239 <    inf | logz: -192.800 +/-  0.116 | dlogz: 36.830 >  0.509                                           /tmp/ipykernel_11110/188716658.py:2: RuntimeWarning: overflow encountered in exp
#   y = np.where(t < t0, b, b+A*np.exp(-alpha*(t-t0)))
# iter: 3513 | bound: 39 | nc: 29 | ncall: 47116 | eff(%):  7.456 | loglstar:   -inf < -179.090 <    inf | logz: -186.209 +/-  0.112 | dlogz: 36.683 >  0.509                                           /tmp/ipykernel_11110/188716658.py:2: RuntimeWarning: overflow encountered in exp
#   y = np.where(t < t0, b, b+A*np.exp(-alpha*(t-t0)))
# iter: 3620 | bound: 45 | nc: 205 | ncall: 51319 | eff(%):  7.054 | loglstar:   -inf < -178.985 <    inf | logz: -186.005 +/-  0.112 | dlogz: 36.265 >  0.509                                          /tmp/ipykernel_11110/188716658.py:2: RuntimeWarning: overflow encountered in exp
#   y = np.where(t < t0, b, b+A*np.exp(-alpha*(t-t0)))
# iter: 3629 | bound: 46 | nc: 345 | ncall: 52389 | eff(%):  6.927 | loglstar:   -inf < -178.983 <    inf | logz: -185.991 +/-  0.112 | dlogz: 36.233 >  0.509                                          /tmp/ipykernel_11110/188716658.py:2: RuntimeWarning: overflow encountered in exp
#   y = np.where(t < t0, b, b+A*np.exp(-alpha*(t-t0)))
# iter: 7626 | +500 | bound: 93 | nc: 1 | ncall: 87941 | eff(%):  9.293 | loglstar:   -inf < -140.843 <    inf | logz: -155.340 +/-  0.168 | dlogz:  0.001 >  0.509
# Bayes Factor (Burst/Gaussian) = 89.84509059719169
# Burst model is preferred.
